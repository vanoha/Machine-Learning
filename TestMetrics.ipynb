# %% [markdown]
# <a href="https://colab.research.google.com/github/vanoha/Machine-Learning/blob/main/TestMetrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import sklearn as skl
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# # Preprocessing data

# %%
parkinson_data = pd.read_csv("parkinsons.data")
parkinson_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  ...          D2         PPE
# count   195.000000    195.000000  ...  195.000000  195.000000
# mean    154.228641    197.104918  ...    2.381826    0.206552
# std      41.390065     91.491548  ...    0.382799    0.090119
# min      88.333000    102.145000  ...    1.423287    0.044539
# 25%     117.572000    134.862500  ...    2.099125    0.137451
# 50%     148.790000    175.829000  ...    2.361532    0.194052
# 75%     182.769000    224.205500  ...    2.636456    0.252980
# max     260.105000    592.030000  ...    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
parkinson_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
msno.matrix(parkinson_data)

# %%
parkinson_data.hist(figsize=(15,20))
plt.suptitle("Histogram for each numeric input variable")
plt.show()

# %%
ax = sns.countplot(x="status", data=parkinson_data)

# %%
for i in parkinson_data.columns[1:]:
    fig, ax = plt.subplots()
    ax.boxplot(parkinson_data[i])
    plt.ylabel(i)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#
# ...

# %%
feat = parkinson_data.drop(columns=['status', 'name'])
labels = parkinson_data['status']

scaler = MinMaxScaler((-1, 1))

X = scaler.fit_transform(feat)
y = labels

# %% [markdown]
# # Model training and prediction

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

i = 0.05
print("Test part of dataset  ", "Accurancy")
while i <= 0.35:
  x_train, x_test, y_train, y_test=train_test_split(X, y, test_size=i)
  xgb_mod.fit(x_train, y_train)

  y_prediction = xgb_mod.predict(x_test)

  print(round(i, 2), "                   ", round(accuracy_score(y_test, y_prediction) * 100, 2))
  i += 0.01
# Out:
# Test part of dataset   Accurancy
# 0.05                     100.0
# 0.06                     100.0
# 0.07                     92.86
# 0.08                     81.25
# 0.09                     83.33
# 0.1                     90.0
# 0.11                     90.91
# 0.12                     87.5
# 0.13                     100.0
# 0.14                     96.43
# 0.15                     96.67
# 0.16                     96.88
# 0.17                     91.18
# 0.18                     86.11
# 0.19                     89.47
# 0.2                     92.5
# 0.21                     95.12
# 0.22                     93.02
# 0.23                     93.33
# 0.24                     95.74
# 0.25                     91.84
# 0.26                     92.16
# 0.27                     98.11
# 0.28                     87.27
# 0.29                     94.74
# 0.3                     98.31
# 0.31                     90.16
# 0.32                     84.13
# 0.33                     86.15
# ...
